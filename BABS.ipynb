# %%
# %%bash
#
# babs-init \
#     --where_project ~/babs_demo/ \
#     --project_name ~/babs_demo/my_BABS_project \
#     --input BIDS ~/babs_demo/raw_BIDS_multi-ses \
#     --container_ds ~/babs_demo/mriqc-container \
#     --container_name mriqc-24-0-0 \
#     --container_config_yaml_file ~/babs_demo/config_mriqc_demo.yaml \
#     --type_session multi-ses \
#     --type_system slurm
# Out:
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1890: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["name"][i] = input_cli[i][0]
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1891: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["path_in"][i] = input_cli[i][1]
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1892: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["path_now_rel"][i] = op.join("inputs/data", self.df["name"][i])
# [INFO] Running procedure cfg_yoda
# [INFO] == Command start (output follows) =====
# [INFO] == Command exit (modification check follows) =====
# [INFO] Creating a new RIA store at /root/babs_demo/my_BABS_project/output_ria
# [INFO] create siblings 'output' and 'output-storage' ...
# [INFO] Fetching updates for Dataset(/root/babs_demo/my_BABS_project/analysis)
# [INFO] Configure additional publication dependency on "output-storage"
# [INFO] Creating a new RIA store at /root/babs_demo/my_BABS_project/input_ria
# [INFO] create sibling 'input' ...
# [INFO] Fetching updates for Dataset(/root/babs_demo/my_BABS_project/analysis)
# [INFO] Attempting a clone into /root/babs_demo/my_BABS_project/analysis/inputs/data/BIDS
# [INFO] Attempting to clone from /root/babs_demo/raw_BIDS_multi-ses to /root/babs_demo/my_BABS_project/analysis/inputs/data/BIDS
# [INFO] Completed clone attempts for Dataset(/root/babs_demo/my_BABS_project/analysis/inputs/data/BIDS)
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1981: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["path_now_abs"][i] = op.join(analysis_path,
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:2008: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["is_zipped"][i_ds] = False
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:2026: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["path_data_rel"][i_ds] = self.df["path_now_rel"][i_ds]
# [INFO] Attempting a clone into /root/babs_demo/my_BABS_project/analysis/containers
# [INFO] Attempting to clone from /root/babs_demo/mriqc-container to /root/babs_demo/my_BABS_project/analysis/containers
# [INFO] Completed clone attempts for Dataset(/root/babs_demo/my_BABS_project/analysis/containers)
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/utils.py:436: UserWarning: Usually BIDS App depends on TemplateFlow, but environment variable `TEMPLATEFLOW_HOME` was not set up. Therefore, BABS will not bind its directory or inject this environment variable into the container when running the container. This may cause errors.
#   warnings.warn("Usually BIDS App depends on TemplateFlow,"
# [INFO] Determine push target
# [INFO] Push refspecs
# [INFO] Transfer data
# [INFO] Update availability information
# [INFO] Start enumerating objects
# [INFO] Start counting objects
# [INFO] Start compressing objects
# [INFO] Start writing objects
# [INFO] Finished push of Dataset(/root/babs_demo/my_BABS_project/analysis)
# [INFO] Determine push target
# [INFO] Push refspecs
# [INFO] Determine push target
# [INFO] Push refspecs
# [INFO] Transfer data
# [INFO] Transfer data
# [INFO] Update availability information
# [INFO] Start enumerating objects
# [INFO] Start counting objects
# [INFO] Start compressing objects
# [INFO] Start writing objects
# [INFO] Finished push of Dataset(/root/babs_demo/my_BABS_project/analysis)
# [INFO] Finished push of Dataset(/root/babs_demo/my_BABS_project/analysis)
# DataLad version: 1.0.2
#
# project_root of this BABS project: /root/babs_demo/my_BABS_project
# type of data of this BABS project: multi-ses
# job scheduling system of this BABS project: slurm
#
#
# Creating `analysis` folder (also a datalad dataset)...
# run(ok): /root/babs_demo/my_BABS_project/analysis (dataset) [/opt/conda/envs/virtualenv/bin/python /o...]
# create(ok): /root/babs_demo/my_BABS_project/analysis (dataset)
# action summary:
#   create (ok: 1)
#   run (ok: 1)
# add(ok): .gitignore (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 1)
#   save (ok: 1)
# Save BABS project configurations in a YAML file ...
# Path to this yaml file will be: 'analysis/code/babs_proj_config.yaml'
# add(ok): code/babs_proj_config.yaml (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 1)
#   save (ok: 1)
#
# Creating output and input RIA...
# update(ok): . (dataset)
# update(ok): . (dataset)
# configure-sibling(ok): . (sibling)
# create-sibling-ria(ok): /root/babs_demo/my_BABS_project/analysis (dataset)
# action summary:
#   configure-sibling (ok: 1)
#   create-sibling-ria (ok: 1)
#   update (ok: 1)
# update(ok): . (dataset)
# update(ok): . (dataset)
# configure-sibling(ok): . (sibling)
# create-sibling-ria(ok): /root/babs_demo/my_BABS_project/analysis (dataset)
# action summary:
#   configure-sibling (ok: 1)
#   create-sibling-ria (ok: 1)
#   update (ok: 1)
#
# Registering the input dataset(s)...
# Cloning input dataset #1: 'BIDS'
# install(ok): inputs/data/BIDS (dataset)
# add(ok): inputs/data/BIDS (dataset)
# add(ok): .gitmodules (file)
# save(ok): . (dataset)
# add(ok): .gitmodules (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 3)
#   install (ok: 1)
#   save (ok: 2)
#
# Checking whether each input dataset is a zipped or unzipped dataset...
# input dataset 'BIDS' is considered as an unzipped dataset.
# Performing sanity check for any unzipped input dataset...
# add(ok): code/babs_proj_config.yaml (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 1)
#   save (ok: 1)
#
# Adding the container as a sub-dataset of `analysis` dataset...
# install(ok): containers (dataset)
# add(ok): containers (dataset)
# add(ok): .gitmodules (file)
# save(ok): . (dataset)
# add(ok): .gitmodules (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 3)
#   install (ok: 1)
#   save (ok: 2)
#
# Generating a bash script for running container and zipping the outputs...
# This bash script will be named as `mriqc-24-0-0_zip.sh`
#
# Below is the generated `singularity run` command:
# singularity run --cleanenv \
# 	-B ${PWD} \
# 	containers/.datalad/environments/mriqc-24-0-0/image \
# 	inputs/data/BIDS \
# 	outputs \
# 	participant \
# 	--no-sub \
# 	--participant-label "${subid}"
# add(ok): code/mriqc-24-0-0_zip.sh (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 1)
#   save (ok: 1)
#
# Generating a bash script for running jobs at participant (or session) level...
# This bash script will be named as `participant_job.sh`
# add(ok): code/check_setup/call_test_job.sh (file)
# add(ok): code/check_setup/test_job.py (file)
# add(ok): code/participant_job.sh (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 3)
#   save (ok: 1)
#
# Determining the list of subjects (and sessions) to analyze...
# Did not provide `list_sub_file`. Will look into the first input dataset to get the initial inclusion list.
# Did not provide `required files` in `container_config_yaml_file`. Not to filter subjects (or sessions)...
# The final list of included subjects and sessions has been saved to this CSV file: /root/babs_demo/my_BABS_project/analysis/code/sub_ses_final_inclu.csv
# add(ok): code/sub_ses_final_inclu.csv (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 1)
#   save (ok: 1)
#
# Generating a template for job submission calls...
# The template text file will be named as `submit_job_template.yaml`.
# add(ok): code/check_setup/submit_test_job_template.yaml (file)
# add(ok): code/submit_job_template.yaml (file)
# save(ok): . (dataset)
# action summary:
#   add (ok: 2)
#   save (ok: 1)
#
# Final steps...
# DataLad dropping input dataset's contents...
# action summary:
#   drop (notneeded: 2)
# Updating input and output RIA...
# publish(ok): . (dataset) [refs/heads/master->input:refs/heads/master [new branch]]
# publish(ok): . (dataset) [refs/heads/git-annex->input:refs/heads/git-annex [new branch]]
# action summary:
#   publish (ok: 2)
# publish(ok): . (dataset) [refs/heads/master->output:refs/heads/master [new branch]]
# publish(ok): . (dataset) [refs/heads/git-annex->output:refs/heads/git-annex [new branch]]
# action summary:
#   publish (ok: 2)
# Adding an alias 'data' to output RIA store...
#
#
# BABS project has been initialized! Path to this BABS project: '/root/babs_demo/my_BABS_project'
# `babs-init` was successful!

# %% [markdown]
# # `babs-init` was successful but `babs-check-setup` failed

# %%
# !babs-check-setup --project-root ~/babs_demo/my_BABS_project --job-test
# Out:
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1890: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["name"][i] = input_cli[i][0]
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1891: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["path_in"][i] = input_cli[i][1]
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1892: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["path_now_rel"][i] = op.join("inputs/data", self.df["name"][i])
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py:1981: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   self.df["path_now_abs"][i] = op.join(analysis_path,
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/cli.py:839: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   input_ds.df["path_data_rel"][i_ds] = \
# /opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/cli.py:842: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   input_ds.df["is_zipped"][i_ds] = \
# Will check setups of BABS project located at: /root/babs_demo/my_BABS_project
# Will submit a test job for testing; will take longer time.
# Below is the configuration information saved during `babs-init` in file 'analysis/code/babs_proj_config.yaml':
#
# type_session: multi-ses
# type_system: slurm
# input_ds:
#   $INPUT_DATASET_#1:
#     name: BIDS
#     path_in: /root/babs_demo/raw_BIDS_multi-ses
#     path_data_rel: inputs/data/BIDS
#     is_zipped: false
# container:
#   name: mriqc-24-0-0
#   path_in: /root/babs_demo/mriqc-container
#
# Checking the BABS project itself...
# ✓ All good!
#
# Check status of 'analysis' DataLad dataset...
# nothing to save, working tree clean
# ✓ All good!
#
# Checking input dataset(s)...
# ✓ All good!
#
# Checking container datalad dataset...
# ✓ All good!
#
# Checking `analysis/code/` folder...
# ✓ All good!
#
# Checking input and output RIA...
# 	Datalad dataset `analysis`'s siblings:
# .: here(+) [git]
# .: output-storage(+) [ora]
# .: output(-) [/root/babs_demo/my_BABS_project/output_ria/8c9/1b63b-539c-4a7e-a074-45e94eb8c7e4 (git)]
# .: input(-) [/root/babs_demo/my_BABS_project/input_ria/8c9/1b63b-539c-4a7e-a074-45e94eb8c7e4 (git)]
# Traceback (most recent call last):
#   File "/opt/conda/envs/virtualenv/bin/babs-check-setup", line 8, in <module>
#     sys.exit(babs_check_setup_main())
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/cli.py", line 296, in babs_check_setup_main
#     babs_proj.babs_check_setup(input_ds, args.job_test)
#   File "/opt/conda/envs/virtualenv/lib/python3.12/site-packages/babs/babs.py", line 782, in babs_check_setup
#     assert op.exists(actual_output_ria_data_dir)    # make sure this exists
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError

# %%
# !tree ~/babs_demo/my_BABS_project
# Out:
# /root/babs_demo/my_BABS_project
# ├── analysis
# │   ├── CHANGELOG.md
# │   ├── README.md
# │   ├── code
# │   │   ├── README.md
# │   │   ├── babs_proj_config.yaml
# │   │   ├── babs_proj_config.yaml.lock
# │   │   ├── check_setup
# │   │   │   ├── call_test_job.sh
# │   │   │   ├── submit_test_job_template.yaml
# │   │   │   └── test_job.py
# │   │   ├── mriqc-24-0-0_zip.sh
# │   │   ├── participant_job.sh
# │   │   ├── sub_ses_final_inclu.csv
# │   │   └── submit_job_template.yaml
# │   ├── containers
# │   ├── inputs
# │   │   └── data
# │   │       └── BIDS
# │   │           ├── dataset_description.json
# │   │           ├── sub-01
# │   │           │   ├── ses-A
# │   │           │   │   ├── anat
# │   │           │   │   │   ├── sub-01_ses-A_T1w.json
# │   │           │   │   │   └── sub-01_ses-A_T1w.nii.gz -> ../../../.git/annex/objects/Jk/39/MD5E-s23991--907dae00e27d05352148a748e463884d.nii.gz/MD5E-s23991--907dae00e27d05352148a748e463884d.nii.gz
# │   │           │   │   ├── dwi
# │   │           │   │   │   ├── sub-01_ses-A_dwi.bval
# │   │           │   │   │   ├── sub-01_ses-A_dwi.bvec
# │   │           │   │   │   ├── sub-01_ses-A_dwi.json
# │   │           │   │   │   └── sub-01_ses-A_dwi.nii.gz -> ../../../.git/annex/objects/4K/jG/MD5E-s163552--80b7f74d4cf1c84d4a6b60be49295759.nii.gz/MD5E-s163552--80b7f74d4cf1c84d4a6b60be49295759.nii.gz
# │   │           │   │   └── func
# │   │           │   │       ├── sub-01_ses-A_task-BREATHHOLD_acq-1400_bold.json
# │   │           │   │       ├── sub-01_ses-A_task-BREATHHOLD_acq-1400_bold.nii.gz -> ../../../.git/annex/objects/PP/G5/MD5E-s291301--1ed816b88837e17d60f7a925f766f1e8.nii.gz/MD5E-s291301--1ed816b88837e17d60f7a925f766f1e8.nii.gz
# │   │           │   │       ├── sub-01_ses-A_task-BREATHHOLD_acq-1400_events.tsv
# │   │           │   │       ├── sub-01_ses-A_task-CHECKERBOARD_acq-1400_bold.json
# │   │           │   │       ├── sub-01_ses-A_task-CHECKERBOARD_acq-1400_bold.nii.gz -> ../../../.git/annex/objects/52/9k/MD5E-s153970--828c8b060ee3e2a6c03138721fc52f5c.nii.gz/MD5E-s153970--828c8b060ee3e2a6c03138721fc52f5c.nii.gz
# │   │           │   │       ├── sub-01_ses-A_task-CHECKERBOARD_acq-1400_events.tsv
# │   │           │   │       ├── sub-01_ses-A_task-CHECKERBOARD_acq-645_bold.json
# │   │           │   │       ├── sub-01_ses-A_task-CHECKERBOARD_acq-645_bold.nii.gz -> ../../../.git/annex/objects/xV/GF/MD5E-s103222--5cdba29297747be320592ed361c43f92.nii.gz/MD5E-s103222--5cdba29297747be320592ed361c43f92.nii.gz
# │   │           │   │       ├── sub-01_ses-A_task-CHECKERBOARD_acq-645_events.tsv
# │   │           │   │       ├── sub-01_ses-A_task-rest_acq-1400_bold.json
# │   │           │   │       ├── sub-01_ses-A_task-rest_acq-1400_bold.nii.gz -> ../../../.git/annex/objects/wg/57/MD5E-s631517--6a087f1ea31177afc897c047ec303d81.nii.gz/MD5E-s631517--6a087f1ea31177afc897c047ec303d81.nii.gz
# │   │           │   │       ├── sub-01_ses-A_task-rest_acq-645_bold.json
# │   │           │   │       ├── sub-01_ses-A_task-rest_acq-645_bold.nii.gz -> ../../../.git/annex/objects/G0/vw/MD5E-s384266--31fb6633fef2cc1277a1844572199251.nii.gz/MD5E-s384266--31fb6633fef2cc1277a1844572199251.nii.gz
# │   │           │   │       ├── sub-01_ses-A_task-rest_acq-CAP_bold.json
# │   │           │   │       └── sub-01_ses-A_task-rest_acq-CAP_bold.nii.gz -> ../../../.git/annex/objects/2F/35/MD5E-s47003--c152c63298d8cb23b04e087a22ad5d63.nii.gz/MD5E-s47003--c152c63298d8cb23b04e087a22ad5d63.nii.gz
# │   │           │   ├── ses-B
# │   │           │   │   ├── anat
# │   │           │   │   │   ├── sub-01_ses-B_T1w.json
# │   │           │   │   │   ├── sub-01_ses-B_T1w.nii.gz -> ../../../.git/annex/objects/0V/9z/MD5E-s23997--aad77bb883a630053456c31a4dd2a1c6.nii.gz/MD5E-s23997--aad77bb883a630053456c31a4dd2a1c6.nii.gz
# │   │           │   │   │   ├── sub-01_ses-B_T2w.json
# │   │           │   │   │   └── sub-01_ses-B_T2w.nii.gz -> ../../../.git/annex/objects/6g/m3/MD5E-s45941--eb61303cd3c381df6bed2e8e44a8f4d5.nii.gz/MD5E-s45941--eb61303cd3c381df6bed2e8e44a8f4d5.nii.gz
# │   │           │   │   ├── dwi
# │   │           │   │   │   ├── sub-01_ses-B_dwi.bval
# │   │           │   │   │   ├── sub-01_ses-B_dwi.bvec
# │   │           │   │   │   ├── sub-01_ses-B_dwi.json
# │   │           │   │   │   └── sub-01_ses-B_dwi.nii.gz -> ../../../.git/annex/objects/mF/Xp/MD5E-s163579--f857db94553f4cd27ec4ef91e4451af1.nii.gz/MD5E-s163579--f857db94553f4cd27ec4ef91e4451af1.nii.gz
# │   │           │   │   └── func
# │   │           │   │       ├── sub-01_ses-B_task-BREATHHOLD_acq-1400_bold.json
# │   │           │   │       ├── sub-01_ses-B_task-BREATHHOLD_acq-1400_bold.nii.gz -> ../../../.git/annex/objects/v7/1M/MD5E-s291300--03639be439999416b33191403aaa1492.nii.gz/MD5E-s291300--03639be439999416b33191403aaa1492.nii.gz
# │   │           │   │       ├── sub-01_ses-B_task-BREATHHOLD_acq-1400_events.tsv
# │   │           │   │       ├── sub-01_ses-B_task-CHECKERBOARD_acq-1400_bold.json
# │   │           │   │       ├── sub-01_ses-B_task-CHECKERBOARD_acq-1400_bold.nii.gz -> ../../../.git/annex/objects/kJ/14/MD5E-s153966--f079076d4c0aac103210d43573b8c640.nii.gz/MD5E-s153966--f079076d4c0aac103210d43573b8c640.nii.gz
# │   │           │   │       ├── sub-01_ses-B_task-CHECKERBOARD_acq-1400_events.tsv
# │   │           │   │       ├── sub-01_ses-B_task-CHECKERBOARD_acq-645_bold.json
# │   │           │   │       ├── sub-01_ses-B_task-CHECKERBOARD_acq-645_bold.nii.gz -> ../../../.git/annex/objects/gM/2M/MD5E-s103220--89f5570f05f25eeb89f08e202b5a7377.nii.gz/MD5E-s103220--89f5570f05f25eeb89f08e202b5a7377.nii.gz
# │   │           │   │       ├── sub-01_ses-B_task-CHECKERBOARD_acq-645_events.tsv
# │   │           │   │       ├── sub-01_ses-B_task-rest_acq-1400_bold.json
# │   │           │   │       ├── sub-01_ses-B_task-rest_acq-1400_bold.nii.gz -> ../../../.git/annex/objects/WM/mV/MD5E-s631508--fd1ca5971475b72002280eff94c0a14b.nii.gz/MD5E-s631508--fd1ca5971475b72002280eff94c0a14b.nii.gz
# │   │           │   │       ├── sub-01_ses-B_task-rest_acq-645_bold.json
# │   │           │   │       ├── sub-01_ses-B_task-rest_acq-645_bold.nii.gz -> ../../../.git/annex/objects/Vm/w0/MD5E-s384262--06e32887f00883fc65ab2d4a516a184a.nii.gz/MD5E-s384262--06e32887f00883fc65ab2d4a516a184a.nii.gz
# │   │           │   │       ├── sub-01_ses-B_task-rest_acq-CAP_bold.json
# │   │           │   │       └── sub-01_ses-B_task-rest_acq-CAP_bold.nii.gz -> ../../../.git/annex/objects/mp/GK/MD5E-s47003--165f7eca608381b43c2c42b0cc2a4f00.nii.gz/MD5E-s47003--165f7eca608381b43c2c42b0cc2a4f00.nii.gz
# │   │           │   └── ses-C
# │   │           │       ├── anat
# │   │           │       │   ├── sub-01_ses-C_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T1w.json
# │   │           │       │   ├── sub-01_ses-C_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T1w.nii.gz -> ../../../.git/annex/objects/vj/gj/MD5E-s24076--bca67b0bb18a258d67dc9f7c7c0f6821.nii.gz/MD5E-s24076--bca67b0bb18a258d67dc9f7c7c0f6821.nii.gz
# │   │           │       │   ├── sub-01_ses-C_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T2w.json
# │   │           │       │   └── sub-01_ses-C_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T2w.nii.gz -> ../../../.git/annex/objects/zf/k7/MD5E-s46019--941be643272ef78a9b7408621ef304fe.nii.gz/MD5E-s46019--941be643272ef78a9b7408621ef304fe.nii.gz
# │   │           │       ├── dwi
# │   │           │       │   ├── sub-01_ses-C_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.bval
# │   │           │       │   ├── sub-01_ses-C_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.bvec
# │   │           │       │   ├── sub-01_ses-C_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.json
# │   │           │       │   └── sub-01_ses-C_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.nii.gz -> ../../../.git/annex/objects/Zj/vW/MD5E-s163617--c14209b532e24a33071e2ce2d2e72026.nii.gz/MD5E-s163617--c14209b532e24a33071e2ce2d2e72026.nii.gz
# │   │           │       └── func
# │   │           │           ├── sub-01_ses-C_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │           │           ├── sub-01_ses-C_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/4M/Qk/MD5E-s291382--dc1f6151da27b4c951c88e2c97f607a3.nii.gz/MD5E-s291382--dc1f6151da27b4c951c88e2c97f607a3.nii.gz
# │   │           │           ├── sub-01_ses-C_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │           │           ├── sub-01_ses-C_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │           │           ├── sub-01_ses-C_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/Q4/1G/MD5E-s154050--c2619e1c48ff444d7f3a967144e51aec.nii.gz/MD5E-s154050--c2619e1c48ff444d7f3a967144e51aec.nii.gz
# │   │           │           ├── sub-01_ses-C_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │           │           ├── sub-01_ses-C_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │           │           ├── sub-01_ses-C_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/x2/fV/MD5E-s103303--8723b69d88a1fff840d27c2ab9888a2d.nii.gz/MD5E-s103303--8723b69d88a1fff840d27c2ab9888a2d.nii.gz
# │   │           │           ├── sub-01_ses-C_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │           │           ├── sub-01_ses-C_task-rest_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │           │           ├── sub-01_ses-C_task-rest_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/Wf/px/MD5E-s631600--8ead3003cffb24ed02a3f826fc6269f8.nii.gz/MD5E-s631600--8ead3003cffb24ed02a3f826fc6269f8.nii.gz
# │   │           │           ├── sub-01_ses-C_task-rest_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │           │           ├── sub-01_ses-C_task-rest_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/j5/Zf/MD5E-s384346--23995abdeffe8f41603d356a4221e386.nii.gz/MD5E-s384346--23995abdeffe8f41603d356a4221e386.nii.gz
# │   │           │           ├── sub-01_ses-C_task-rest_acq-CAPVARIANTPartialFourierTotalReadoutTime_bold.json
# │   │           │           └── sub-01_ses-C_task-rest_acq-CAPVARIANTPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/JX/1w/MD5E-s47060--3ea02b2207f3e1f82ea99661c8634b17.nii.gz/MD5E-s47060--3ea02b2207f3e1f82ea99661c8634b17.nii.gz
# │   │           └── sub-02
# │   │               ├── ses-A
# │   │               │   ├── anat
# │   │               │   │   ├── sub-02_ses-A_T1w.json
# │   │               │   │   └── sub-02_ses-A_T1w.nii.gz -> ../../../.git/annex/objects/ww/5P/MD5E-s45714--0e8cec4ee3d14d38a8e825ccd260ffbb.nii.gz/MD5E-s45714--0e8cec4ee3d14d38a8e825ccd260ffbb.nii.gz
# │   │               │   └── func
# │   │               │       ├── sub-02_ses-A_task-rest_acq-1400VARIANTNumVolumes_bold.json
# │   │               │       ├── sub-02_ses-A_task-rest_acq-1400VARIANTNumVolumes_bold.nii.gz -> ../../../.git/annex/objects/1M/6v/MD5E-s349050--02786e0a9d41b4dad9625e59e527d8f2.nii.gz/MD5E-s349050--02786e0a9d41b4dad9625e59e527d8f2.nii.gz
# │   │               │       ├── sub-02_ses-A_task-rest_acq-645_bold.json
# │   │               │       └── sub-02_ses-A_task-rest_acq-645_bold.nii.gz -> ../../../.git/annex/objects/Q6/5v/MD5E-s384274--e96a7689bcb926e52d7f6da39529ce55.nii.gz/MD5E-s384274--e96a7689bcb926e52d7f6da39529ce55.nii.gz
# │   │               ├── ses-B
# │   │               │   ├── anat
# │   │               │   │   ├── sub-02_ses-B_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T1w.json
# │   │               │   │   └── sub-02_ses-B_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T1w.nii.gz -> ../../../.git/annex/objects/QM/Vk/MD5E-s45780--0dfb0a01afc32647d6b8551b0f7dfffa.nii.gz/MD5E-s45780--0dfb0a01afc32647d6b8551b0f7dfffa.nii.gz
# │   │               │   ├── dwi
# │   │               │   │   ├── sub-02_ses-B_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.bval
# │   │               │   │   ├── sub-02_ses-B_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.bvec
# │   │               │   │   ├── sub-02_ses-B_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.json
# │   │               │   │   └── sub-02_ses-B_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.nii.gz -> ../../../.git/annex/objects/zq/1G/MD5E-s163620--9e61e88773533fc64925af6219716478.nii.gz/MD5E-s163620--9e61e88773533fc64925af6219716478.nii.gz
# │   │               │   └── func
# │   │               │       ├── sub-02_ses-B_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │               │       ├── sub-02_ses-B_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/Pz/wV/MD5E-s291390--f441b6d14bf28d1e910a68baf8a8f980.nii.gz/MD5E-s291390--f441b6d14bf28d1e910a68baf8a8f980.nii.gz
# │   │               │       ├── sub-02_ses-B_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.json
# │   │               │       ├── sub-02_ses-B_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/2Z/fZ/MD5E-s154060--b71d52ebf179b198a49b871f9a84d72e.nii.gz/MD5E-s154060--b71d52ebf179b198a49b871f9a84d72e.nii.gz
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.json
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/WJ/K0/MD5E-s103315--33aa80cf1e3b175a874e8f5e182b07b6.nii.gz/MD5E-s103315--33aa80cf1e3b175a874e8f5e182b07b6.nii.gz
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.json
# │   │               │       ├── sub-02_ses-B_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │               │       ├── sub-02_ses-B_task-rest_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │               │       ├── sub-02_ses-B_task-rest_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/QV/fw/MD5E-s631608--24680f1fa7e4dab1b49c3973cf6fa1ae.nii.gz/MD5E-s631608--24680f1fa7e4dab1b49c3973cf6fa1ae.nii.gz
# │   │               │       ├── sub-02_ses-B_task-rest_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │               │       ├── sub-02_ses-B_task-rest_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/Xm/m4/MD5E-s384358--a82c4dd46a64f9b9bb8e92fc0410781e.nii.gz/MD5E-s384358--a82c4dd46a64f9b9bb8e92fc0410781e.nii.gz
# │   │               │       ├── sub-02_ses-B_task-rest_acq-CAPVARIANTPartialFourierTotalReadoutTime_bold.json
# │   │               │       └── sub-02_ses-B_task-rest_acq-CAPVARIANTPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/vQ/K0/MD5E-s47070--be4841d855726e8c560060b9f43d11e9.nii.gz/MD5E-s47070--be4841d855726e8c560060b9f43d11e9.nii.gz
# │   │               └── ses-D
# │   │                   ├── anat
# │   │                   │   ├── sub-02_ses-D_T2w.json
# │   │                   │   ├── sub-02_ses-D_T2w.nii.gz -> ../../../.git/annex/objects/qq/g7/MD5E-s45941--2e20a7943a116225b3f3a2edcc27e277.nii.gz/MD5E-s45941--2e20a7943a116225b3f3a2edcc27e277.nii.gz
# │   │                   │   ├── sub-02_ses-D_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T1w.json
# │   │                   │   └── sub-02_ses-D_acq-VARIANTParallelReductionFactorInPlanePartialFourierPhaseEncodingDirection_T1w.nii.gz -> ../../../.git/annex/objects/72/Jf/MD5E-s45789--a8c90353a1c193f2ea37b3e5486154d6.nii.gz/MD5E-s45789--a8c90353a1c193f2ea37b3e5486154d6.nii.gz
# │   │                   ├── dwi
# │   │                   │   ├── sub-02_ses-D_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.bval
# │   │                   │   ├── sub-02_ses-D_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.bvec
# │   │                   │   ├── sub-02_ses-D_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.json
# │   │                   │   └── sub-02_ses-D_acq-VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_dwi.nii.gz -> ../../../.git/annex/objects/3k/2j/MD5E-s163612--814430dca1b3fdb2cd4bf146b3dc228b.nii.gz/MD5E-s163612--814430dca1b3fdb2cd4bf146b3dc228b.nii.gz
# │   │                   └── func
# │   │                       ├── sub-02_ses-D_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │                       ├── sub-02_ses-D_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/8q/51/MD5E-s291355--d4fbb9c3daaa4d965572795f0f064e13.nii.gz/MD5E-s291355--d4fbb9c3daaa4d965572795f0f064e13.nii.gz
# │   │                       ├── sub-02_ses-D_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.json
# │   │                       ├── sub-02_ses-D_task-BREATHHOLD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/j6/F4/MD5E-s154018--b34b43b1f54e7a80e3c83855695c3df3.nii.gz/MD5E-s154018--b34b43b1f54e7a80e3c83855695c3df3.nii.gz
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.json
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/mv/Zk/MD5E-s103279--19ad8154f9934cbaf5ad2d0ce9d8d6b4.nii.gz/MD5E-s103279--19ad8154f9934cbaf5ad2d0ce9d8d6b4.nii.gz
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.json
# │   │                       ├── sub-02_ses-D_task-CHECKERBOARD_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_events.tsv
# │   │                       ├── sub-02_ses-D_task-rest_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │                       ├── sub-02_ses-D_task-rest_acq-1400VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/3q/PJ/MD5E-s631568--fdbf81fb1e4eacf4432e22305125afaf.nii.gz/MD5E-s631568--fdbf81fb1e4eacf4432e22305125afaf.nii.gz
# │   │                       ├── sub-02_ses-D_task-rest_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.json
# │   │                       ├── sub-02_ses-D_task-rest_acq-645VARIANTMultibandAccelerationFactorPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/Zx/P0/MD5E-s384323--45590d5938fbe5026b86849634b36f39.nii.gz/MD5E-s384323--45590d5938fbe5026b86849634b36f39.nii.gz
# │   │                       ├── sub-02_ses-D_task-rest_acq-CAPVARIANTPartialFourierTotalReadoutTime_bold.json
# │   │                       └── sub-02_ses-D_task-rest_acq-CAPVARIANTPartialFourierTotalReadoutTime_bold.nii.gz -> ../../../.git/annex/objects/jF/52/MD5E-s47037--305d95ae05acebbc8193b7b54af1d736.nii.gz/MD5E-s47037--305d95ae05acebbc8193b7b54af1d736.nii.gz
# │   └── logs
# ├── input_ria
# │   ├── 8c9
# │   │   └── 1b63b-539c-4a7e-a074-45e94eb8c7e4
# │   │       ├── HEAD
# │   │       ├── archives
# │   │       ├── branches
# │   │       ├── config
# │   │       ├── description
# │   │       ├── hooks
# │   │       │   ├── applypatch-msg.sample
# │   │       │   ├── commit-msg.sample
# │   │       │   ├── fsmonitor-watchman.sample
# │   │       │   ├── post-update.sample
# │   │       │   ├── pre-applypatch.sample
# │   │       │   ├── pre-commit.sample
# │   │       │   ├── pre-merge-commit.sample
# │   │       │   ├── pre-push.sample
# │   │       │   ├── pre-rebase.sample
# │   │       │   ├── pre-receive.sample
# │   │       │   ├── prepare-commit-msg.sample
# │   │       │   ├── push-to-checkout.sample
# │   │       │   ├── sendemail-validate.sample
# │   │       │   └── update.sample
# │   │       ├── info
# │   │       │   └── exclude
# │   │       ├── objects
# │   │       │   ├── 02
# │   │       │   │   └── 9f5da79c4903fd7590f3a367a2fecf399d70a7
# │   │       │   ├── 07
# │   │       │   │   └── e2c2a0795a6e5859bf72fb0395c44e816c523f
# │   │       │   ├── 0b
# │   │       │   │   └── a4c677868a7f07f545b358159d3a3ed2d87239
# │   │       │   ├── 0c
# │   │       │   │   └── 24f0e1f48058f7cae0cc817599e49696ad71b0
# │   │       │   ├── 0e
# │   │       │   │   └── e754d647439fa26c0ccc43880aa33c60887192
# │   │       │   ├── 17
# │   │       │   │   └── c84f17c832bcf1cc3797014b90cf25c1c4d318
# │   │       │   ├── 1b
# │   │       │   │   └── 4245ed0c4dcdfcea450a7e29e7124cc28beca9
# │   │       │   ├── 1e
# │   │       │   │   └── d9d2f6b504b19c0f01816178233c68835f758c
# │   │       │   ├── 24
# │   │       │   │   └── a7ef57846d258f340f3ae9fb2540c7cf4b9266
# │   │       │   ├── 2b
# │   │       │   │   └── 4fea1bec590a245273ea801ec1c51b5a472281
# │   │       │   ├── 2f
# │   │       │   │   └── 10d4e7fab227db77b31072e14b5f1601f18876
# │   │       │   ├── 30
# │   │       │   │   ├── 0f44f4a025c85bb639f93567b02eee36f83b3f
# │   │       │   │   └── 4e79aea04c81a7ed43edd7b53c6d9e25576996
# │   │       │   ├── 33
# │   │       │   │   └── 4a02e885c63f68794c90320deb86745dea991b
# │   │       │   ├── 36
# │   │       │   │   └── ae0bcb3067031d0e7df8d5523034d513d574cf
# │   │       │   ├── 3c
# │   │       │   │   └── 011631cd438ccac2d4facea7236854ccbfa1d8
# │   │       │   ├── 3d
# │   │       │   │   └── 201a44bdc5812a3e29249a45366883dfa3d4d2
# │   │       │   ├── 3f
# │   │       │   │   └── 7c814f396362104be44babdece2c40068a17b5
# │   │       │   ├── 42
# │   │       │   │   └── 55a74a68afad82fb5f32cb1823f3d06cce7a7c
# │   │       │   ├── 43
# │   │       │   │   └── 73f99b2259b359ed3b6334bb18bc84aa8e1cc1
# │   │       │   ├── 45
# │   │       │   │   └── b32f7e34b3e4d371549620dec639e7aa0188e9
# │   │       │   ├── 48
# │   │       │   │   └── 220babe971b1264542d93216351bc856236bea
# │   │       │   ├── 4b
# │   │       │   │   └── 825dc642cb6eb9a060e54bf8d69288fbee4904
# │   │       │   ├── 59
# │   │       │   │   ├── 28185081410e652fcb8b4446fae9caf43288e5
# │   │       │   │   └── c0e9f6b386382c44e75b1d542659256f6a08f7
# │   │       │   ├── 5d
# │   │       │   │   └── 4caf551ea192e569112d009300aba7c3f902a7
# │   │       │   ├── 5f
# │   │       │   │   └── 7c70c576ca417d43a157f9617d05715a70be80
# │   │       │   ├── 66
# │   │       │   │   └── d8c131bfc404ebf6c4d8ab9c6e964a39a66865
# │   │       │   ├── 67
# │   │       │   │   └── 1566df3b5916db30200b572b3a0342e91a6074
# │   │       │   ├── 68
# │   │       │   │   └── 4636944f47b8cb60f860144363d72b3d9fc3ef
# │   │       │   ├── 6d
# │   │       │   │   ├── 30803344d0a19730157c480d5b1ba0b57b5d41
# │   │       │   │   └── 345987c15befc0ce837628802b7d969c40ccfe
# │   │       │   ├── 71
# │   │       │   │   └── 0c6e893d962ddbb4ea1925aa88587b30654335
# │   │       │   ├── 7b
# │   │       │   │   └── 1faf384a12578171caf8bf24cccbbd7ca14c44
# │   │       │   ├── 7d
# │   │       │   │   └── dc02a68ed4cc6fdf61d35df9448834d01a7147
# │   │       │   ├── 80
# │   │       │   │   └── c0276e5da62bd1d8005cc0f359953a432f4e54
# │   │       │   ├── 81
# │   │       │   │   └── 6f22a2cd7bf4d4ccf4d98681cca1fed59f6934
# │   │       │   ├── 8b
# │   │       │   │   └── b01676c41c4899e4348e77a7e79e1b183e1cb5
# │   │       │   ├── 91
# │   │       │   │   └── 9b5e56571e66a6275dc34320e1cd50ed5a7346
# │   │       │   ├── 93
# │   │       │   │   └── 377c105f2997a113dbdd543548221cf2d67466
# │   │       │   ├── 94
# │   │       │   │   └── b570eac65b1d11c79fed128d3e95ffeff6ef92
# │   │       │   ├── ab
# │   │       │   │   └── e958490c14c01a5a01907b1789e63f95eda64e
# │   │       │   ├── ad
# │   │       │   │   └── acf774534665a17820a8af519fe8fe2260bf8f
# │   │       │   ├── af
# │   │       │   │   └── 926ef0c359556ac1d36d71f7e173d97b893ff2
# │   │       │   ├── b1
# │   │       │   │   └── caa6174935dfbe6cc0c5b7c87831d8a33e98a8
# │   │       │   ├── b8
# │   │       │   │   └── c7367f434e7dcaa625bb55ea29c0e24bf4b444
# │   │       │   ├── b9
# │   │       │   │   └── 671fa61eeeec5be76c6721af2fab68dd5ad601
# │   │       │   ├── ba
# │   │       │   │   └── 132ab786184f1b6f4fc0aef1d21f9535f2fb8f
# │   │       │   ├── bb
# │   │       │   │   └── 98f59797a5a8f13d5076a34753055c0d6c11ea
# │   │       │   ├── c8
# │   │       │   │   └── 35ef9eb12a5759fd443f332d791f7ae8d83fed
# │   │       │   ├── ce
# │   │       │   │   └── 25aec3b6d95fd688c2f0fd8d3d37c37c7770b7
# │   │       │   ├── d7
# │   │       │   │   └── f193d8f49ce271b88b80061ed9307ba8b503c6
# │   │       │   ├── d8
# │   │       │   │   └── 67036c6221b58a9b91bef584cf39df0a41117d
# │   │       │   ├── dc
# │   │       │   │   └── f2ac8bfafe4b35bb7f4be4d2c32d86bfb3e5fb
# │   │       │   ├── e2
# │   │       │   │   └── b084e719b0ccff6177fd3e5018d4d2e2c631df
# │   │       │   ├── e5
# │   │       │   │   └── c14f7471f8193f2ca0d04de27711047359be75
# │   │       │   ├── e6
# │   │       │   │   ├── 61739e93a638692cf06f236df3a043090f9968
# │   │       │   │   └── 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
# │   │       │   ├── e7
# │   │       │   │   └── b2e793fc11f919b93aa13730dc0ad35e1923dc
# │   │       │   ├── e8
# │   │       │   │   └── 086c5678ae62ffea9baec8437db521bb70729b
# │   │       │   ├── f3
# │   │       │   │   └── dde7648350d91e8dc45a86f7971b028ff18ce3
# │   │       │   ├── f4
# │   │       │   │   └── 115134fea55121d1c9f65fbca0f566b9f768ed
# │   │       │   ├── fe
# │   │       │   │   └── 20a82b094a6d956f45e73a2fa6da4851134a60
# │   │       │   ├── info
# │   │       │   └── pack
# │   │       ├── refs
# │   │       │   ├── heads
# │   │       │   │   ├── git-annex
# │   │       │   │   └── master
# │   │       │   └── tags
# │   │       └── ria-layout-version
# │   ├── error_logs
# │   └── ria-layout-version
# └── output_ria
#     ├── 8c9
#     │   └── 1b63b-539c-4a7e-a074-45e94eb8c7e4
#     │       ├── HEAD
#     │       ├── annex
#     │       │   └── objects
#     │       ├── archives
#     │       ├── branches
#     │       ├── config
#     │       ├── config.dataladlock
#     │       ├── description
#     │       ├── hooks
#     │       │   ├── applypatch-msg.sample
#     │       │   ├── commit-msg.sample
#     │       │   ├── fsmonitor-watchman.sample
#     │       │   ├── post-update.sample
#     │       │   ├── pre-applypatch.sample
#     │       │   ├── pre-commit.sample
#     │       │   ├── pre-merge-commit.sample
#     │       │   ├── pre-push.sample
#     │       │   ├── pre-rebase.sample
#     │       │   ├── pre-receive.sample
#     │       │   ├── prepare-commit-msg.sample
#     │       │   ├── push-to-checkout.sample
#     │       │   ├── sendemail-validate.sample
#     │       │   └── update.sample
#     │       ├── info
#     │       │   └── exclude
#     │       ├── objects
#     │       │   ├── 02
#     │       │   │   └── 9f5da79c4903fd7590f3a367a2fecf399d70a7
#     │       │   ├── 07
#     │       │   │   └── e2c2a0795a6e5859bf72fb0395c44e816c523f
#     │       │   ├── 0b
#     │       │   │   └── a4c677868a7f07f545b358159d3a3ed2d87239
#     │       │   ├── 0c
#     │       │   │   └── 24f0e1f48058f7cae0cc817599e49696ad71b0
#     │       │   ├── 0e
#     │       │   │   └── e754d647439fa26c0ccc43880aa33c60887192
#     │       │   ├── 17
#     │       │   │   └── c84f17c832bcf1cc3797014b90cf25c1c4d318
#     │       │   ├── 1b
#     │       │   │   └── 4245ed0c4dcdfcea450a7e29e7124cc28beca9
#     │       │   ├── 1e
#     │       │   │   └── d9d2f6b504b19c0f01816178233c68835f758c
#     │       │   ├── 24
#     │       │   │   └── a7ef57846d258f340f3ae9fb2540c7cf4b9266
#     │       │   ├── 2b
#     │       │   │   └── 4fea1bec590a245273ea801ec1c51b5a472281
#     │       │   ├── 2f
#     │       │   │   └── 10d4e7fab227db77b31072e14b5f1601f18876
#     │       │   ├── 30
#     │       │   │   ├── 0f44f4a025c85bb639f93567b02eee36f83b3f
#     │       │   │   └── 4e79aea04c81a7ed43edd7b53c6d9e25576996
#     │       │   ├── 33
#     │       │   │   └── 4a02e885c63f68794c90320deb86745dea991b
#     │       │   ├── 36
#     │       │   │   └── ae0bcb3067031d0e7df8d5523034d513d574cf
#     │       │   ├── 3c
#     │       │   │   └── 011631cd438ccac2d4facea7236854ccbfa1d8
#     │       │   ├── 3d
#     │       │   │   └── 201a44bdc5812a3e29249a45366883dfa3d4d2
#     │       │   ├── 3f
#     │       │   │   └── 7c814f396362104be44babdece2c40068a17b5
#     │       │   ├── 42
#     │       │   │   └── 55a74a68afad82fb5f32cb1823f3d06cce7a7c
#     │       │   ├── 43
#     │       │   │   └── 73f99b2259b359ed3b6334bb18bc84aa8e1cc1
#     │       │   ├── 45
#     │       │   │   └── b32f7e34b3e4d371549620dec639e7aa0188e9
#     │       │   ├── 48
#     │       │   │   └── 220babe971b1264542d93216351bc856236bea
#     │       │   ├── 4b
#     │       │   │   └── 825dc642cb6eb9a060e54bf8d69288fbee4904
#     │       │   ├── 59
#     │       │   │   ├── 28185081410e652fcb8b4446fae9caf43288e5
#     │       │   │   └── c0e9f6b386382c44e75b1d542659256f6a08f7
#     │       │   ├── 5d
#     │       │   │   └── 4caf551ea192e569112d009300aba7c3f902a7
#     │       │   ├── 5f
#     │       │   │   └── 7c70c576ca417d43a157f9617d05715a70be80
#     │       │   ├── 66
#     │       │   │   └── d8c131bfc404ebf6c4d8ab9c6e964a39a66865
#     │       │   ├── 67
#     │       │   │   └── 1566df3b5916db30200b572b3a0342e91a6074
#     │       │   ├── 68
#     │       │   │   └── 4636944f47b8cb60f860144363d72b3d9fc3ef
#     │       │   ├── 6d
#     │       │   │   ├── 30803344d0a19730157c480d5b1ba0b57b5d41
#     │       │   │   └── 345987c15befc0ce837628802b7d969c40ccfe
#     │       │   ├── 71
#     │       │   │   └── 0c6e893d962ddbb4ea1925aa88587b30654335
#     │       │   ├── 7b
#     │       │   │   └── 1faf384a12578171caf8bf24cccbbd7ca14c44
#     │       │   ├── 7d
#     │       │   │   └── dc02a68ed4cc6fdf61d35df9448834d01a7147
#     │       │   ├── 80
#     │       │   │   └── c0276e5da62bd1d8005cc0f359953a432f4e54
#     │       │   ├── 81
#     │       │   │   └── 6f22a2cd7bf4d4ccf4d98681cca1fed59f6934
#     │       │   ├── 8b
#     │       │   │   └── b01676c41c4899e4348e77a7e79e1b183e1cb5
#     │       │   ├── 91
#     │       │   │   └── 9b5e56571e66a6275dc34320e1cd50ed5a7346
#     │       │   ├── 93
#     │       │   │   └── 377c105f2997a113dbdd543548221cf2d67466
#     │       │   ├── 94
#     │       │   │   └── b570eac65b1d11c79fed128d3e95ffeff6ef92
#     │       │   ├── ab
#     │       │   │   └── e958490c14c01a5a01907b1789e63f95eda64e
#     │       │   ├── ad
#     │       │   │   └── acf774534665a17820a8af519fe8fe2260bf8f
#     │       │   ├── af
#     │       │   │   └── 926ef0c359556ac1d36d71f7e173d97b893ff2
#     │       │   ├── b1
#     │       │   │   └── caa6174935dfbe6cc0c5b7c87831d8a33e98a8
#     │       │   ├── b8
#     │       │   │   └── c7367f434e7dcaa625bb55ea29c0e24bf4b444
#     │       │   ├── b9
#     │       │   │   └── 671fa61eeeec5be76c6721af2fab68dd5ad601
#     │       │   ├── ba
#     │       │   │   └── 132ab786184f1b6f4fc0aef1d21f9535f2fb8f
#     │       │   ├── bb
#     │       │   │   └── 98f59797a5a8f13d5076a34753055c0d6c11ea
#     │       │   ├── c8
#     │       │   │   └── 35ef9eb12a5759fd443f332d791f7ae8d83fed
#     │       │   ├── ce
#     │       │   │   └── 25aec3b6d95fd688c2f0fd8d3d37c37c7770b7
#     │       │   ├── d7
#     │       │   │   └── f193d8f49ce271b88b80061ed9307ba8b503c6
#     │       │   ├── d8
#     │       │   │   └── 67036c6221b58a9b91bef584cf39df0a41117d
#     │       │   ├── dc
#     │       │   │   └── f2ac8bfafe4b35bb7f4be4d2c32d86bfb3e5fb
#     │       │   ├── e2
#     │       │   │   └── b084e719b0ccff6177fd3e5018d4d2e2c631df
#     │       │   ├── e5
#     │       │   │   └── c14f7471f8193f2ca0d04de27711047359be75
#     │       │   ├── e6
#     │       │   │   ├── 61739e93a638692cf06f236df3a043090f9968
#     │       │   │   └── 9de29bb2d1d6434b8b29ae775ad8c2e48c5391
#     │       │   ├── e7
#     │       │   │   └── b2e793fc11f919b93aa13730dc0ad35e1923dc
#     │       │   ├── e8
#     │       │   │   └── 086c5678ae62ffea9baec8437db521bb70729b
#     │       │   ├── f3
#     │       │   │   └── dde7648350d91e8dc45a86f7971b028ff18ce3
#     │       │   ├── f4
#     │       │   │   └── 115134fea55121d1c9f65fbca0f566b9f768ed
#     │       │   ├── fe
#     │       │   │   └── 20a82b094a6d956f45e73a2fa6da4851134a60
#     │       │   ├── info
#     │       │   └── pack
#     │       ├── refs
#     │       │   ├── heads
#     │       │   │   ├── git-annex
#     │       │   │   └── master
#     │       │   └── tags
#     │       └── ria-layout-version
#     ├── alias
#     │   └── data -> file:///root/babs_demo/my_BABS_project/output_ria/8c9/1b63b-539c-4a7e-a074-45e94eb8c7e4
#     ├── error_logs
#     └── ria-layout-version
#
# 183 directories, 308 files
